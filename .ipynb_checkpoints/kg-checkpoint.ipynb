# %%
import re
import nltk
from nltk.tokenize import sent_tokenize
import spacy
from spacy import displacy
from termcolor import colored
from extraction import findSVOs
import en_core_web_lg

# %%
with open('sample.txt', 'r') as file:
    text = file.read()

# %%
# removing honorifics from the text

honorifics = "Ms. |Mrs. |Mr. |Dr. "
text = re.sub(honorifics, "", text)

# %%
# getting the NER using spaCy

nlp = en_core_web_lg.load()
doc = nlp(text)

entities = set()
for ent in doc.ents:
    entities.add(ent.text)
print(entities)

displacy.render(doc, style='ent', jupyter=True)
# Out:
# {'dendrodendritic synapses', 'the von Neumann', 'the von Neumann model'}
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">A biological neural network is composed of a groups of chemically connected or functionally associated neurons. A single neuron may be connected to many other neurons and the total number of neurons and connections in a network may be extensive. Connections, called synapses, are usually formed from axons to dendrites, though
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     dendrodendritic synapses
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ...

# %%
'''
intermediate = ''
flag = False
entity = ''
for w in tagged_words:
    if w[1] in ['ORGANIZATION', 'PERSON', 'GPE', 'MONEY']:
        if flag:
            entity += (' ' + w[0])
        else:
            flag = True
            entity = w[0]
            print(colored(intermediate, 'cyan'))
            intermediate = ''
    else:
        if (not flag):
            tagged = nltk.pos_tag(w)
            intermediate += (' ' + w[0])
        else:
            print(colored(entity, 'magenta'))
            entity = ''
            flag = False
            intermediate = w[0] 
'''
# Out:
# "\nintermediate = ''\nflag = False\nentity = ''\nfor w in tagged_words:\n    if w[1] in ['ORGANIZATION', 'PERSON', 'GPE', 'MONEY']:\n        if flag:\n            entity += (' ' + w[0])\n        else:\n            flag = True\n            entity = w[0]\n            print(colored(intermediate, 'cyan'))\n            intermediate = ''\n    else:\n        if (not flag):\n            tagged = nltk.pos_tag(w)\n            intermediate += (' ' + w[0])\n        else:\n            print(colored(entity, 'magenta'))\n            entity = ''\n            flag = False\n            intermediate = w[0] \n"

# %%
f = sent_tokenize(text)

# %%
i=0

for sentence in f: 
    print('Sentence %d' %i)
    print('\n%s\n' %sentence)
    i+=1
    tokens = nlp(sentence)
    svos = findSVOs(tokens)
    print(svos)
    print('\n\n<<------------------------------------------------------>>\n\n')
# Out:
# Sentence 0
#
# A biological neural network is composed of a groups of chemically connected or functionally associated neurons.
#
# [('a groups of neurons', 'compose', 'A biological neural network'), ('neurons', 'associated')]
#
#
# <<------------------------------------------------------>>
#
#
# Sentence 1
#
# A single neuron may be connected to many other neurons and the total number of neurons and connections in a network may be extensive.
#
# [('many other neurons', 'connect', 'A single neuron'), ('the total number of in a network', 'connect', 'A single neuron')]
#
#
# <<------------------------------------------------------>>
#
#
# Sentence 2
#
# Connections, called synapses, are usually formed from axons to dendrites, though dendrodendritic synapses and other connections are possible.
#
# [('synapses', 'call', 'Connections ,'), ('axons to dendrites', 'form', 'Connections ,')]
#
#
# <<------------------------------------------------------>>
#
#
# Sentence 3
#
# ...

# %%
import spacy
from spacy import displacy

for sentence in f:
    doc = nlp(sentence)
    displacy.render(doc, style="dep")
    # print(doc['arcs'])
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="5802210b761f48379b8bade5b993ec6d-0" class="displacy" width="4950" height="662.0" direction="ltr" style="max-width: none; height: 662.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">According</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
# ...

# %%
# !python -m spacy download en_core_web_lg
# Out:
# ...
#      |████████████████████████████████| 782.7 MB 5.0 MB/s eta 0:00:016    |███████▉                        | 190.3 MB 5.7 MB/s eta 0:01:45     |██████████▍                     | 253.8 MB 6.1 MB/s eta 0:01:27     |█████████████▋                  | 331.7 MB 5.7 MB/s eta 0:01:20     |██████████████▋                 | 358.6 MB 6.1 MB/s eta 0:01:10     |█████████████████████████████▏  | 712.2 MB 5.6 MB/s eta 0:00:13
# ...
#   Created wheel for en-core-web-lg: filename=en_core_web_lg-2.3.1-py3-none-any.whl size=782936123 sha256=79a92d49bcb083fb9782bec5c401f40c3f12f8669548f0b4b3aea2cef47f7a66
#   Stored in directory: /private/var/folders/sr/f97fk8y57w5_72ntv41mhk8c0000gn/T/pip-ephem-wheel-cache-ue3i_oha/wheels/8b/bb/bb/bdc918f4b37d930a1be9ed876e7b2c2ee518a34803d78a248e
# Successfully built en-core-web-lg
# ...
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_lg')

# %%
text = "Percy is good-natured, friendly, brave, and willing to risk his life to save his friends, strangers, and even his enemies. He is angered by Thalia Grace because their personalities are similar, they argue even though they are good friends. Percy has a sarcastic sense of humor and is funny in his writing."
